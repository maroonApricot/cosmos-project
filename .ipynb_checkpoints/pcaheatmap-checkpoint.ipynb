# %% [markdown]
# # Import data into python

# %%
# Load some libraries 
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import numpy as np
from sklearn.decomposition import PCA

sns.set_context("paper", font_scale=2)

# %%
# Read in metadata file
metadata = pd.read_csv("/data/class/cosmos2023/PUBLIC/shai_hulud/data/mirna/actual_data/mirna_metadata.csv")

# Read in data
merged_df = pd.read_csv("/data/class/cosmos2023/PUBLIC/shai_hulud/data/mirna/actual_data/mirna_cpm_matrix.csv", index_col = 0)

# %%
merged_df.head()
# Out:
#                       ENCFF784UWQ  ENCFF094EFP  ENCFF810XKL  ENCFF641TJV  \
# ENSMUSG00000093015.1     0.000000     0.000000     0.000000     0.000000
# ENSMUSG00000093970.1     0.000000     0.000000     0.000000     0.000000
# ENSMUSG00000076135.1     0.000000     0.000000     0.000000     0.000000
# ENSMUSG00000098555.1     0.000000     0.000000     0.000000     0.000000
# ENSMUSG00000099183.1     0.447441     0.270617     0.410765     1.046254
#
#                       ENCFF859KXI  ENCFF286MEN  ENCFF256FTO  ENCFF841RXZ  \
# ENSMUSG00000093015.1      0.00000     0.000000     0.000000     0.000000
# ENSMUSG00000093970.1      0.00000     0.000000     0.000000     0.000000
# ENSMUSG00000076135.1      0.00000     0.000000     0.000000     0.000000
# ENSMUSG00000098555.1      0.00000     0.000000     0.000000     0.000000
# ENSMUSG00000099183.1      0.25502     3.622939     1.010693     2.451725
#
#                       ENCFF782ZKC  ENCFF224PRR  ...  ENCFF431VHL  ENCFF629KYY  \
# ENSMUSG00000093015.1     0.000000       0.0000  ...     0.000000     0.000000
# ENSMUSG00000093970.1     0.000000       0.0000  ...     0.000000     0.000000
# ENSMUSG00000076135.1     0.000000       0.0000  ...     0.000000     0.000000
# ENSMUSG00000098555.1     0.000000       0.0000  ...     0.000000     0.000000
# ENSMUSG00000099183.1     2.738685       0.9669  ...     0.282104     1.879263
#
#                       ENCFF430EME  ENCFF007FOL  Ctrl_0hr_A_new  \
# ENSMUSG00000093015.1     0.000000     0.000000             0.0
# ENSMUSG00000093970.1     0.000000     0.000000             0.0
# ENSMUSG00000076135.1     0.000000     0.000000             0.0
# ENSMUSG00000098555.1     0.000000     0.000000             0.0
# ENSMUSG00000099183.1     0.820783     0.984804             0.0
#
#                       Ctrl_0hr_B_new  Ctrl_0hr_C_new  Ctrl_72hr_A_new  \
# ENSMUSG00000093015.1             0.0        0.000000         0.000000
# ENSMUSG00000093970.1             0.0        0.000000         0.000000
# ENSMUSG00000076135.1             0.0        0.000000         0.000000
# ENSMUSG00000098555.1             0.0        0.000000         0.000000
# ENSMUSG00000099183.1             0.0        0.284426         1.859317
#
#                       Ctrl_72hr_B_new  Ctrl_72hr_C_new
# ENSMUSG00000093015.1         0.000000         0.000000
# ENSMUSG00000093970.1         0.000000         0.000000
# ENSMUSG00000076135.1         0.000000         0.000000
# ENSMUSG00000098555.1         0.000000         0.000000
# ENSMUSG00000099183.1         0.551599         1.196178
#
# [5 rows x 57 columns]

# %% [markdown]
# # PCA (principal component analysis)
# [5-minute explanation of PCA on Youtube](https://www.youtube.com/watch?v=HMOI_lkzW08&t=28s)

# %%
input_df = merged_df.transpose() # transpose the matrix
data = input_df.values # just get the numbers
pca = PCA(merged_df.shape[1]) # compute the same # of PCs as samples
pca.fit(data)
# Out:
# PCA(n_components=57)

# %%
# Make df to plot the percent variance explained
pca_df = pd.DataFrame(data=pca.explained_variance_ratio_,
                      columns=['prop_variance'])

# compute percent variance from proportion variance
pca_df['pct_variance'] = pca_df.prop_variance*100
pca_df['PC'] = list(range(1, merged_df.shape[1]+1))
print(pca_df)

# Use Seaborn library to make categorical bar plot
ax = sns.catplot(data=pca_df, x='PC', y='pct_variance', kind='bar')

# Add nice x and y axis labels
ax.set(ylabel='Percent of variance explained', xlabel='Principal Component')
# Out:
#     prop_variance  pct_variance  PC
# 0    3.515043e-01  3.515043e+01   1
# 1    2.151844e-01  2.151844e+01   2
# 2    1.720204e-01  1.720204e+01   3
# 3    8.153404e-02  8.153404e+00   4
# 4    5.460171e-02  5.460171e+00   5
# 5    3.642676e-02  3.642676e+00   6
# 6    2.631169e-02  2.631169e+00   7
# 7    1.683288e-02  1.683288e+00   8
# 8    1.239782e-02  1.239782e+00   9
# 9    7.458860e-03  7.458860e-01  10
# 10   5.674782e-03  5.674782e-01  11
# 11   4.703062e-03  4.703062e-01  12
# 12   3.504034e-03  3.504034e-01  13
# 13   2.198516e-03  2.198516e-01  14
# 14   1.992402e-03  1.992402e-01  15
# 15   1.325792e-03  1.325792e-01  16
# 16   1.215916e-03  1.215916e-01  17
# 17   8.943558e-04  8.943558e-02  18
# 18   7.240438e-04  7.240438e-02  19
# 19   5.216330e-04  5.216330e-02  20
# 20   4.614831e-04  4.614831e-02  21
# 21   4.206527e-04  4.206527e-02  22
# 22   3.078916e-04  3.078916e-02  23
# 23   2.448491e-04  2.448491e-02  24
# 24   2.295317e-04  2.295317e-02  25
# 25   2.067710e-04  2.067710e-02  26
# 26   1.910808e-04  1.910808e-02  27
# 27   1.531519e-04  1.531519e-02  28
# 28   1.350931e-04  1.350931e-02  29
# 29   1.194531e-04  1.194531e-02  30
# 30   9.031790e-05  9.031790e-03  31
# 31   6.920023e-05  6.920023e-03  32
# 32   5.069811e-05  5.069811e-03  33
# 33   4.551890e-05  4.551890e-03  34
# 34   4.375291e-05  4.375291e-03  35
# 35   3.736667e-05  3.736667e-03  36
# 36   2.830958e-05  2.830958e-03  37
# 37   2.410003e-05  2.410003e-03  38
# 38   2.063680e-05  2.063680e-03  39
# 39   1.915475e-05  1.915475e-03  40
# 40   1.753207e-05  1.753207e-03  41
# 41   1.324871e-05  1.324871e-03  42
# 42   1.010910e-05  1.010910e-03  43
# 43   7.955326e-06  7.955326e-04  44
# 44   5.159874e-06  5.159874e-04  45
# 45   3.655240e-06  3.655240e-04  46
# 46   3.146674e-06  3.146674e-04  47
# 47   2.665793e-06  2.665793e-04  48
# 48   2.183473e-06  2.183473e-04  49
# 49   1.918697e-06  1.918697e-04  50
# 50   1.618857e-06  1.618857e-04  51
# 51   1.328593e-06  1.328593e-04  52
# 52   1.225637e-06  1.225637e-04  53
# 53   8.717308e-07  8.717308e-05  54
# 54   5.898064e-07  5.898064e-05  55
# 55   5.001451e-07  5.001451e-05  56
# 56   6.932199e-32  6.932199e-30  57
# /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/axisgrid.py:88: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# first calculate the PCA representation of the data
pca_data = pca.transform(data) 
cols = ['PC{} ({:.1f}%)'.format(pc, var) for pc, var in zip(pca_df.PC, pca_df.pct_variance)]
print(cols)
pca_df = pd.DataFrame(data=pca_data, columns=cols)
pca_df.set_index(input_df.index, inplace=True)


# Perform a merge based on matching indices
pca_df = pca_df.merge(metadata, left_index=True, right_on='File.accession')
# Out:
# ['PC1 (35.2%)', 'PC2 (21.5%)', 'PC3 (17.2%)', 'PC4 (8.2%)', 'PC5 (5.5%)', 'PC6 (3.6%)', 'PC7 (2.6%)', 'PC8 (1.7%)', 'PC9 (1.2%)', 'PC10 (0.7%)', 'PC11 (0.6%)', 'PC12 (0.5%)', 'PC13 (0.4%)', 'PC14 (0.2%)', 'PC15 (0.2%)', 'PC16 (0.1%)', 'PC17 (0.1%)', 'PC18 (0.1%)', 'PC19 (0.1%)', 'PC20 (0.1%)', 'PC21 (0.0%)', 'PC22 (0.0%)', 'PC23 (0.0%)', 'PC24 (0.0%)', 'PC25 (0.0%)', 'PC26 (0.0%)', 'PC27 (0.0%)', 'PC28 (0.0%)', 'PC29 (0.0%)', 'PC30 (0.0%)', 'PC31 (0.0%)', 'PC32 (0.0%)', 'PC33 (0.0%)', 'PC34 (0.0%)', 'PC35 (0.0%)', 'PC36 (0.0%)', 'PC37 (0.0%)', 'PC38 (0.0%)', 'PC39 (0.0%)', 'PC40 (0.0%)', 'PC41 (0.0%)', 'PC42 (0.0%)', 'PC43 (0.0%)', 'PC44 (0.0%)', 'PC45 (0.0%)', 'PC46 (0.0%)', 'PC47 (0.0%)', 'PC48 (0.0%)', 'PC49 (0.0%)', 'PC50 (0.0%)', 'PC51 (0.0%)', 'PC52 (0.0%)', 'PC53 (0.0%)', 'PC54 (0.0%)', 'PC55 (0.0%)', 'PC56 (0.0%)', 'PC57 (0.0%)']

# %%
ax = sns.scatterplot(data=pca_df, x=cols[0], y=cols[1], hue='Biosample.term.name')

# Add legend
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='x-small')

# %% [markdown]
# ## make it pretty!

# %%
# Make a mini dictionary to assign color to fshd status
c_dict = {'FSHD2': 'green', 
          'Control': 'orange' }

ax = sns.scatterplot(data=pca_df, x=cols[0], y=cols[1], 
                     s=150, # size of point
                     hue='fshd_status', palette=c_dict, style='day_of_differentiation')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='medium')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [109], in <cell line: 5>()
#       1 # Make a mini dictionary to assign color to fshd status
#       2 c_dict = {'FSHD2': 'green',
#       3           'Control': 'orange' }
# ----> 5 ax = sns.scatterplot(data=pca_df, x=cols[0], y=cols[1],
#       6                      s=150, # size of point
#       7                      hue='fshd_status', palette=c_dict, style='day_of_differentiation')
#       8 plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='medium')
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/relational.py:808, in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     793 @_deprecate_positional_args
#     794 def scatterplot(
#     795     *,
#    (...)
#     804     legend="auto", ax=None, **kwargs
#     805 ):
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
#     809         data=data, variables=variables,
#     810         x_bins=x_bins, y_bins=y_bins,
#     811         estimator=estimator, ci=ci, n_boot=n_boot,
#     812         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#     813     )
#     815     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     816     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/relational.py:587, in _ScatterPlotter.__init__(self, data, variables, x_bins, y_bins, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     571 def __init__(
#     572     self, *,
#     573     data=None, variables={},
#    (...)
#     581     # the kind of plot to draw, but for the time being we need to set
#     582     # this information so the SizeMapping can use it
#     583     self._default_size_range = (
#     584         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     585     )
# --> 587     super().__init__(data=data, variables=variables)
#     589     self.alpha = alpha
#     590     self.legend = legend
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/_core.py:605, in VectorPlotter.__init__(self, data, variables)
#     603 def __init__(self, data=None, variables={}):
# --> 605     self.assign_variables(data, variables)
#     607     for var, cls in self._semantic_mappings.items():
#     608
#     609         # Create the mapping function
#     610         map_func = partial(cls.map, plotter=self)
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/_core.py:668, in VectorPlotter.assign_variables(self, data, variables)
#     666 else:
#     667     self.input_format = "long"
# --> 668     plot_data, variables = self._assign_variables_longform(
#     669         data, **variables,
#     670     )
#     672 self.plot_data = plot_data
#     673 self.variables = variables
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/_core.py:903, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     898 elif isinstance(val, (str, bytes)):
#     899
#     900     # This looks like a column name but we don't know what it means!
#     902     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903     raise ValueError(err)
#     905 else:
#     906
#     907     # Otherwise, assume the value is itself data
#     908
#     909     # Raise when data object is present and a vector can't matched
#     910     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `fshd_status` for parameter `hue`

# %%
# Get the top weighted genes for PC1 and PC2
top_genes_pc1 = input_df.columns[pca.components_[0].argsort()[::-1]]
top_genes_pc2 = input_df.columns[pca.components_[1].argsort()[::-1]]

# Print the top weighted genes for PC1
print("Top genes for PC1:")
print(top_genes_pc1.to_frame().head(n=15))

# Print the top weighted genes for PC2
print("Top genes for PC2:")
print(top_genes_pc2.to_frame().head(n=15))
# Out:
# Top genes for PC1:
#                                          0
# ENSMUSG00000065559.1  ENSMUSG00000065559.1
# ENSMUSG00000070076.2  ENSMUSG00000070076.2
# ENSMUSG00000070139.1  ENSMUSG00000070139.1
# ENSMUSG00000065503.1  ENSMUSG00000065503.1
# ENSMUSG00000065477.3  ENSMUSG00000065477.3
# ENSMUSG00000065437.1  ENSMUSG00000065437.1
# ENSMUSG00000065480.1  ENSMUSG00000065480.1
# ENSMUSG00000065475.2  ENSMUSG00000065475.2
# ENSMUSG00000065564.1  ENSMUSG00000065564.1
# ENSMUSG00000076251.1  ENSMUSG00000076251.1
# ENSMUSG00000065479.2  ENSMUSG00000065479.2
# ENSMUSG00000076219.1  ENSMUSG00000076219.1
# ENSMUSG00000070080.1  ENSMUSG00000070080.1
# ENSMUSG00000065498.4  ENSMUSG00000065498.4
# ENSMUSG00000065408.1  ENSMUSG00000065408.1
# Top genes for PC2:
#                                          0
# ENSMUSG00000065455.1  ENSMUSG00000065455.1
# ENSMUSG00000065445.3  ENSMUSG00000065445.3
# ENSMUSG00000065529.1  ENSMUSG00000065529.1
# ENSMUSG00000065611.1  ENSMUSG00000065611.1
# ENSMUSG00000065405.3  ENSMUSG00000065405.3
# ENSMUSG00000065440.1  ENSMUSG00000065440.1
# ENSMUSG00000065406.3  ENSMUSG00000065406.3
# ENSMUSG00000065564.1  ENSMUSG00000065564.1
# ENSMUSG00000065408.1  ENSMUSG00000065408.1
# ENSMUSG00000065453.1  ENSMUSG00000065453.1
# ENSMUSG00000065610.1  ENSMUSG00000065610.1
# ENSMUSG00000065437.1  ENSMUSG00000065437.1
# ENSMUSG00000065599.2  ENSMUSG00000065599.2
# ENSMUSG00000065475.2  ENSMUSG00000065475.2
# ENSMUSG00000065446.1  ENSMUSG00000065446.1

# %%
merged_df.head()
# Out:
#                       ENCFF784UWQ  ENCFF094EFP  ENCFF810XKL  ENCFF641TJV  \
# ENSMUSG00000065406.3     2.348521     2.315111     2.345190     2.346687
# ENSMUSG00000065599.2     2.295345     2.273172     2.312879     2.309132
# ENSMUSG00000065611.1     2.351293     2.321461     2.298492     2.291187
# ENSMUSG00000065440.1     2.312054     2.274129     2.331046     2.331099
# ENSMUSG00000065445.3     2.345724     2.326071     2.316722     2.321543
#
#                       ENCFF859KXI  ENCFF286MEN  ENCFF256FTO  ENCFF841RXZ  \
# ENSMUSG00000065406.3     2.344900     2.372602     2.345816     2.346572
# ENSMUSG00000065599.2     2.317199     2.339125     2.330601     2.331246
# ENSMUSG00000065611.1     2.314917     2.347021     2.323612     2.322980
# ENSMUSG00000065440.1     2.331339     2.366820     2.333488     2.333801
# ENSMUSG00000065445.3     2.310177     2.347330     2.314543     2.324746
#
#                       ENCFF782ZKC  ENCFF224PRR  ...  ENCFF431VHL  ENCFF629KYY  \
# ENSMUSG00000065406.3     2.354173     2.354031  ...     2.325628     2.335794
# ENSMUSG00000065599.2     2.324963     2.327391  ...     2.295987     2.290010
# ENSMUSG00000065611.1     2.317386     2.319120  ...     2.304877     2.300401
# ENSMUSG00000065440.1     2.346835     2.347723  ...     2.323171     2.319610
# ENSMUSG00000065445.3     2.317471     2.325068  ...     2.320766     2.321723
#
#                       ENCFF430EME  ENCFF007FOL  Ctrl_0hr_A_new  \
# ENSMUSG00000065406.3     2.321070     2.335416        2.319742
# ENSMUSG00000065599.2     2.295460     2.290329        2.301041
# ENSMUSG00000065611.1     2.302370     2.302942        2.364716
# ENSMUSG00000065440.1     2.318527     2.317838        2.295188
# ENSMUSG00000065445.3     2.320800     2.318026        2.323941
#
#                       Ctrl_0hr_B_new  Ctrl_0hr_C_new  Ctrl_72hr_A_new  \
# ENSMUSG00000065406.3        2.314742        2.318757         2.293564
# ENSMUSG00000065599.2        2.304352        2.298961         2.303674
# ENSMUSG00000065611.1        2.367313        2.367687         2.313939
# ENSMUSG00000065440.1        2.290995        2.284153         2.236818
# ENSMUSG00000065445.3        2.325609        2.326454         2.290225
#
#                       Ctrl_72hr_B_new  Ctrl_72hr_C_new
# ENSMUSG00000065406.3         2.293592         2.291500
# ENSMUSG00000065599.2         2.302828         2.302742
# ENSMUSG00000065611.1         2.315280         2.314115
# ENSMUSG00000065440.1         2.238888         2.235562
# ENSMUSG00000065445.3         2.290476         2.289086
#
# [5 rows x 57 columns]

# %% [markdown]
# # Heatmap

# %%
# order matrix based on expression so we can get some highly-expressed guys
# (but usually for these you'll want to curate the set of genes in a more intelligent way)


merged_df['total'] = merged_df.sum(axis=1)
merged_df.sort_values(by='total', ascending=False, inplace=True)
# merged_df.drop('total', axis=1, inplace=True)

# log2 transform and add pseudocount -- common way to transform RNA-seq data for visualization
merged_df = np.log2(merged_df + 1) 

# show top 15 genes
merged_df_top15 = merged_df[:15]

# %%
# Use clustermap function in seaborn to make heatmap
ax = sns.clustermap(data=merged_df_top15)

# %% [markdown]
# ## Check expression of any gene you're interested in

# %%
# subset df for the genes that were in the figure

mygenes = ['PAX7', 'MYOD1', 'MYF5', 'MYOG', 'MYH1', 'MYH2', 'MYH4', 'ATF3']

merged_df_my_genes = merged_df[merged_df.index.isin(mygenes)]

# %%
# Turn off column clustering, change color map, and adjust the yticklabels to label every row
ax = sns.clustermap(data=merged_df_my_genes, col_cluster=False, cmap="mako")
plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0)  # y axis labels were getting rotated for some reason
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [115], in <cell line: 2>()
#       1 # Turn off column clustering, change color map, and adjust the yticklabels to label every row
# ----> 2 ax = sns.clustermap(data=merged_df_my_genes, col_cluster=False, cmap="mako")
#       3 plt.setp(ax.ax_heatmap.get_yticklabels(), rotation=0)  # y axis labels were getting rotated for some reason
#       4 plt.show()
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/matrix.py:1406, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1248 """
#    1249 Plot a matrix dataset as a hierarchically-clustered heatmap.
#    1250
#    (...)
#    1398     >>> g = sns.clustermap(iris, z_score=0, cmap="vlag")
#    1399 """
#    1400 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1401                       row_colors=row_colors, col_colors=col_colors,
#    1402                       z_score=z_score, standard_scale=standard_scale,
#    1403                       mask=mask, dendrogram_ratio=dendrogram_ratio,
#    1404                       colors_ratio=colors_ratio, cbar_pos=cbar_pos)
# -> 1406 return plotter.plot(metric=metric, method=method,
#    1407                     colorbar_kws=cbar_kws,
#    1408                     row_cluster=row_cluster, col_cluster=col_cluster,
#    1409                     row_linkage=row_linkage, col_linkage=col_linkage,
#    1410                     tree_kws=tree_kws, **kwargs)
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/matrix.py:1219, in ClusterGrid.plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1215     kws.pop("square")
#    1217 colorbar_kws = {} if colorbar_kws is None else colorbar_kws
# -> 1219 self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1220                       row_linkage=row_linkage, col_linkage=col_linkage,
#    1221                       tree_kws=tree_kws)
#    1222 try:
#    1223     xind = self.dendrogram_col.reordered_ind
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/matrix.py:1064, in ClusterGrid.plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#    1060 def plot_dendrograms(self, row_cluster, col_cluster, metric, method,
#    1061                      row_linkage, col_linkage, tree_kws):
#    1062     # Plot the row dendrogram
#    1063     if row_cluster:
# -> 1064         self.dendrogram_row = dendrogram(
#    1065             self.data2d, metric=metric, method=method, label=False, axis=0,
#    1066             ax=self.ax_row_dendrogram, rotate=True, linkage=row_linkage,
#    1067             tree_kws=tree_kws
#    1068         )
#    1069     else:
#    1070         self.ax_row_dendrogram.set_xticks([])
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/matrix.py:779, in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     736 @_deprecate_positional_args
#     737 def dendrogram(
#     738     data, *,
#     739     linkage=None, axis=1, label=True, metric='euclidean',
#     740     method='average', rotate=False, tree_kws=None, ax=None
#     741 ):
#     742     """Draw a tree diagram of relationships within a matrix
#     743
#     744     Parameters
#    (...)
#     777
#     778     """
# --> 779     plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     780                                  metric=metric, method=method,
#     781                                  label=label, rotate=rotate)
#     782     if ax is None:
#     783         ax = plt.gca()
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/matrix.py:589, in _DendrogramPlotter.__init__(self, data, linkage, metric, method, axis, label, rotate)
#     586 self.rotate = rotate
#     588 if linkage is None:
# --> 589     self.linkage = self.calculated_linkage
#     590 else:
#     591     self.linkage = linkage
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/matrix.py:656, in _DendrogramPlotter.calculated_linkage(self)
#     652         msg = ("Clustering large matrix with scipy. Installing "
#     653                "`fastcluster` may give better performance.")
#     654         warnings.warn(msg)
# --> 656 return self._calculate_linkage_scipy()
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/seaborn/matrix.py:624, in _DendrogramPlotter._calculate_linkage_scipy(self)
#     623 def _calculate_linkage_scipy(self):
# --> 624     linkage = hierarchy.linkage(self.array, method=self.method,
#     625                                 metric=self.metric)
#     626     return linkage
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/scipy/cluster/hierarchy.py:1068, in linkage(y, method, metric, optimal_ordering)
#    1064 if not np.all(np.isfinite(y)):
#    1065     raise ValueError("The condensed distance matrix must contain only "
#    1066                      "finite values.")
# -> 1068 n = int(distance.num_obs_y(y))
#    1069 method_code = _LINKAGE_METHODS[method]
#    1071 if method == 'single':
#
# File /opt/apps/python/3.8.0/lib/python3.8/site-packages/scipy/spatial/distance.py:2564, in num_obs_y(Y)
#    2562 k = Y.shape[0]
#    2563 if k == 0:
# -> 2564     raise ValueError("The number of observations cannot be determined on "
#    2565                      "an empty distance matrix.")
#    2566 d = int(np.ceil(np.sqrt(k * 2)))
#    2567 if (d * (d - 1) / 2) != k:
#
# ValueError: The number of observations cannot be determined on an empty distance matrix.
