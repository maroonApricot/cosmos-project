# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
import pandas as pd
import numpy as np
from adjustText import adjust_text
import matplotlib.pylab as plt
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
data = pd.read_csv("data_adj/fixed_counts_matrix.tsv", sep="\t")
#here is where you filter which samples you want
data = data.filter(items=['gene_id',
                'LB_10.5_NA_1', 'LB_10.5_NA_2','LB_11.5_NA_1', 'LB_11.5_NA_2',
                'G_4_F_1', 'G_4_F_2','G_4_M_1', 'G_4_M_2',
                'SM_0_NA_1', 'SM_0_NA_2',
                'MB_1', 'MB_2','MB_3', 'MB_4','MB_5',
                'MT_1', 'MT_2', 'MT_3', 'MT_4', 'MT_5'])
data = data.set_index(data["gene_id"])
data = data.drop('gene_id', axis=1)

# %%
data.head()
# Out:
#                       LB_10.5_NA_1  LB_10.5_NA_2  LB_11.5_NA_1  LB_11.5_NA_2  \
# gene_id
# ENSMUSG00000099183.1             0             0             0             0
# ENSMUSG00000065559.1            96           350          1561          1909
# ENSMUSG00000065480.1             4            25            92            83
# ENSMUSG00000065405.3         18023         20008         13458         15665
# ENSMUSG00000065567.1           125            57           111            71
#
#                       G_4_F_1  G_4_F_2  G_4_M_1  G_4_M_2  SM_0_NA_1  \
# gene_id
# ENSMUSG00000099183.1        2        4        1        8          1
# ENSMUSG00000065559.1   720323   517475   652657      101     298316
# ENSMUSG00000065480.1      444      373      427       10       2556
# ENSMUSG00000065405.3    26029    16861    16800    17258      17696
# ENSMUSG00000065567.1      213      240      186     1986         51
#
#                       SM_0_NA_2    MB_1    MB_2    MB_3    MB_4    MB_5  \
# gene_id
# ENSMUSG00000099183.1          4      12       4       0       0       1
# ENSMUSG00000065559.1     447669   70786   15451   27143   24389   27329
# ENSMUSG00000065480.1       4440    2433     306     334     359    1088
# ENSMUSG00000065405.3      20188  223146  132440  125913  135138  120392
# ENSMUSG00000065567.1         87    5289    1440    2074    1710    2018
#
#                          MT_1     MT_2     MT_3     MT_4     MT_5
# gene_id
# ENSMUSG00000099183.1       12       19        6        2        4
# ENSMUSG00000065559.1  2584038  4111798  1074677  1300194  1256891
# ENSMUSG00000065480.1   103180   104254    26475    26033    21244
# ENSMUSG00000065405.3    46398    64996    27729    28878    25335
# ENSMUSG00000065567.1      535      812      517      529      416

# %%
metadata = pd.read_csv("data_adj/metadata.tsv", sep="\t",
                      usecols=["File.accession", "Biosample.term.name", "Age", "Sample"])

# %%
# Filter metadata DataFrame based on matching samples in merged_df
metadata_filtered = metadata[metadata['Sample'].isin(data.columns)].copy()

# Sort filtered_metadata based on the order of columns in merged_df
metadata_filtered['Sample'] = pd.Categorical(metadata_filtered['Sample'], categories=data.columns)
metadata_filtered.sort_values('Sample', inplace=True)

# %%
filtering = {'Biosample.term.name': ['gastrocnemius', 'limb'],#whatever you need from the biosample names
             'Age': ["ED_10.5","PND_04"]}
group = 'Age' # change to the group you're interested in making the comparison in

# %%
metadata_selected = metadata_filtered.copy(deep=True)

# %%
for col in filtering.keys():
    metadata_selected = metadata_selected[metadata_selected[col].isin(filtering[col])]

# %%
metadata_selected
# Out:
#    File.accession Biosample.term.name      Age        Sample
# 33    ENCFF398EBM                limb  ED_10.5  LB_10.5_NA_1
# 34    ENCFF065GME                limb  ED_10.5  LB_10.5_NA_2
# 2     ENCFF810XKL       gastrocnemius   PND_04       G_4_F_1
# 3     ENCFF641TJV       gastrocnemius   PND_04       G_4_F_2
# 4     ENCFF859KXI       gastrocnemius   PND_04       G_4_M_1
# 5     ENCFF286MEN       gastrocnemius   PND_04       G_4_M_2

# %%
metadata_selected.index = metadata_selected['Sample']
data_selected = data.loc[:, metadata_selected['Sample']]

# %%
data_selected
# Out:
#                       LB_10.5_NA_1  LB_10.5_NA_2  G_4_F_1  G_4_F_2  G_4_M_1  \
# gene_id
# ENSMUSG00000099183.1             0             0        2        4        1
# ENSMUSG00000065559.1            96           350   720323   517475   652657
# ENSMUSG00000065480.1             4            25      444      373      427
# ENSMUSG00000065405.3         18023         20008    26029    16861    16800
# ENSMUSG00000065567.1           125            57      213      240      186
# ...                            ...           ...      ...      ...      ...
# ENSMUSG00000099172.1             0             0        0        0        0
# ENSMUSG00000093219.1             2             0        0        0        0
# ENSMUSG00000065602.1           210           251    10619     7689     8256
# ENSMUSG00000065536.2           812          1260    16682    12544    14124
# ENSMUSG00000106618.1             0             0        0        0        0
#
#                       G_4_M_2
# gene_id
# ENSMUSG00000099183.1        8
# ENSMUSG00000065559.1      101
# ENSMUSG00000065480.1       10
# ENSMUSG00000065405.3    17258
# ENSMUSG00000065567.1     1986
# ...                       ...
# ENSMUSG00000099172.1        0
# ENSMUSG00000093219.1        0
# ENSMUSG00000065602.1    10667
# ENSMUSG00000065536.2     8378
# ENSMUSG00000106618.1        0
#
# [1096 rows x 6 columns]

# %%
metadata_selected
# Out:
#              File.accession Biosample.term.name      Age        Sample
# Sample
# LB_10.5_NA_1    ENCFF398EBM                limb  ED_10.5  LB_10.5_NA_1
# LB_10.5_NA_2    ENCFF065GME                limb  ED_10.5  LB_10.5_NA_2
# G_4_F_1         ENCFF810XKL       gastrocnemius   PND_04       G_4_F_1
# G_4_F_2         ENCFF641TJV       gastrocnemius   PND_04       G_4_F_2
# G_4_M_1         ENCFF859KXI       gastrocnemius   PND_04       G_4_M_1
# G_4_M_2         ENCFF286MEN       gastrocnemius   PND_04       G_4_M_2

# %%
dds = DeseqDataSet(
    counts=data_selected.T,
    clinical=metadata_selected,
    design_factors=group,
    refit_cooks=True)

dds.deseq2()
stat_res = DeseqStats(dds, 
                      contrast=[group] + filtering[group])
stat_res.summary()
# Out:
# Fitting size factors...
# ... done in 0.00 seconds.
# /opt/apps/python/3.8.0/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Fitting dispersions...
# ... done in 5.73 seconds.
#
# Fitting dispersion trend curve...
# ... done in 1.05 seconds.
#
# Fitting MAP dispersions...
# ... done in 4.23 seconds.
#
# Fitting LFCs...
# ... done in 1.32 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# ... done in 1.04 seconds.
#
# Log2 fold change & Wald test p-value: Age ED_10.5 vs PND_04
#                            baseMean  log2FoldChange     lfcSE       stat  \
# gene_id
# ENSMUSG00000099183.1       3.347070       -5.069052  2.717486  -1.865346
# ENSMUSG00000065559.1  326663.093750      -11.371823  1.633300  -6.962485
# ENSMUSG00000065480.1     222.289001       -4.755702  1.206515  -3.941685
# ENSMUSG00000065405.3   19843.832031       -0.559931  0.257646  -2.173255
# ENSMUSG00000065567.1     660.740051       -3.782775  1.222003  -3.095553
# ...                             ...             ...       ...        ...
# ENSMUSG00000099172.1       0.000000             NaN       NaN        NaN
# ENSMUSG00000093219.1       0.239755        1.768744  4.425366   0.399683
# ENSMUSG00000065602.1    7467.917480       -5.921497  0.590088 -10.034932
# ENSMUSG00000065536.2    9984.934570       -4.127267  0.528282  -7.812623
# ENSMUSG00000106618.1       0.000000             NaN       NaN        NaN
#
#                             pvalue          padj
# gene_id
# ENSMUSG00000099183.1  6.213290e-02  1.153570e-01
# ENSMUSG00000065559.1  3.343229e-12  3.670284e-11
# ENSMUSG00000065480.1  8.091132e-05  3.854737e-04
# ENSMUSG00000065405.3  2.976111e-02  6.450370e-02
# ENSMUSG00000065567.1           NaN           NaN
# ...                            ...           ...
# ENSMUSG00000099172.1           NaN           NaN
# ENSMUSG00000093219.1  6.893899e-01           NaN
# ENSMUSG00000065602.1  1.070331e-23  3.179512e-22
# ENSMUSG00000065536.2  5.601004e-15  7.644613e-14
# ENSMUSG00000106618.1           NaN           NaN
#
# [1096 rows x 6 columns]

# %%
l2fc_cutoff = 2 # Log 2 fold change; usually 0.5 - 2
pval_cutoff = 0.05 # 0.01 is even better than 0.05

# %%
annot = pd.read_csv("data_adj/mirna_id_to_name.tsv", sep="\t")
annot.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df = stat_res.results_df.copy(deep=True)

# %%
# Find the machine-specific lowest non-zero value
lowest_nonzero_value = df['padj'][df['padj'] > 0].min()

# Replace 0 with the lowest non-zero value
df['padj'] = np.where(df['padj'] == 0, lowest_nonzero_value, df['padj'])

df = df.dropna()
df = df.merge(annot, left_index=True, right_on='gene_id')
df
# Out:
#           baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0    326663.093750      -11.371823  1.633300  -6.962485  3.343229e-12
# 1       222.289001       -4.755702  1.206515  -3.941685  8.091132e-05
# 818   19843.832031       -0.559931  0.257646  -2.173255  2.976111e-02
# 5         6.415480        0.434372  0.926449   0.468856  6.391723e-01
# 9     67945.406250       -0.390454  0.604998  -0.645380  5.186807e-01
# ..             ...             ...       ...        ...           ...
# 909      24.309687        0.036747  0.925358   0.039711  9.683237e-01
# 805   31132.349609       -0.454599  0.650263  -0.699099  4.844899e-01
# 810       8.871367       -0.077952  1.397236  -0.055790  9.555088e-01
# 814    7467.917480       -5.921497  0.590088 -10.034932  1.070331e-23
# 815    9984.934570       -4.127267  0.528282  -7.812623  5.601004e-15
#
#              padj               gene_id   gene_name
# 0    3.670284e-11  ENSMUSG00000065559.1      Mir206
# 1    3.854737e-04  ENSMUSG00000065480.1     Mir133b
# 818  6.450370e-02  ENSMUSG00000065405.3      Mir30a
# 5    7.292843e-01  ENSMUSG00000098752.1     Mir6897
# 9    6.321179e-01  ENSMUSG00000065468.1      Mir26b
# ..            ...                   ...         ...
# 909  9.741105e-01  ENSMUSG00000093102.1     Mir3475
# 805  5.996750e-01  ENSMUSG00000076011.1      Mir652
# 810  9.708893e-01  ENSMUSG00000080331.1     Mir1298
# 814  3.179512e-22  ENSMUSG00000065602.1  Mirlet7f-2
# 815  7.644613e-14  ENSMUSG00000065536.2       Mir98
#
# [479 rows x 8 columns]

# %%
# Calculate -log10(padj)
df['nlog10padj'] = -np.log10(df['padj'])

# Add labels to DE column based on our cutoffs above
df['DE'] = "No"
df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange > l2fc_cutoff)] = "Up"
df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange < -l2fc_cutoff)] = "Down"
# Out:
# /tmp/ipykernel_1764438/1959988433.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange > l2fc_cutoff)] = "Up"
# /tmp/ipykernel_1764438/1959988433.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange < -l2fc_cutoff)] = "Down"

# %%
df
# Out:
#           baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# 0    326663.093750      -11.371823  1.633300  -6.962485  3.343229e-12
# 1       222.289001       -4.755702  1.206515  -3.941685  8.091132e-05
# 818   19843.832031       -0.559931  0.257646  -2.173255  2.976111e-02
# 5         6.415480        0.434372  0.926449   0.468856  6.391723e-01
# 9     67945.406250       -0.390454  0.604998  -0.645380  5.186807e-01
# ..             ...             ...       ...        ...           ...
# 909      24.309687        0.036747  0.925358   0.039711  9.683237e-01
# 805   31132.349609       -0.454599  0.650263  -0.699099  4.844899e-01
# 810       8.871367       -0.077952  1.397236  -0.055790  9.555088e-01
# 814    7467.917480       -5.921497  0.590088 -10.034932  1.070331e-23
# 815    9984.934570       -4.127267  0.528282  -7.812623  5.601004e-15
#
#              padj               gene_id   gene_name  nlog10padj    DE
# 0    3.670284e-11  ENSMUSG00000065559.1      Mir206   10.435300  Down
# 1    3.854737e-04  ENSMUSG00000065480.1     Mir133b    3.414005  Down
# 818  6.450370e-02  ENSMUSG00000065405.3      Mir30a    1.190415    No
# 5    7.292843e-01  ENSMUSG00000098752.1     Mir6897    0.137103    No
# 9    6.321179e-01  ENSMUSG00000065468.1      Mir26b    0.199202    No
# ..            ...                   ...         ...         ...   ...
# 909  9.741105e-01  ENSMUSG00000093102.1     Mir3475    0.011392    No
# 805  5.996750e-01  ENSMUSG00000076011.1      Mir652    0.222084    No
# 810  9.708893e-01  ENSMUSG00000080331.1     Mir1298    0.012830    No
# 814  3.179512e-22  ENSMUSG00000065602.1  Mirlet7f-2   21.497640  Down
# 815  7.644613e-14  ENSMUSG00000065536.2       Mir98   13.116644  Down
#
# [479 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

df['label'] = df.gene_name
df.label[df.DE == "No"] = ""

# Create the figure
fig, ax = plt.subplots()

# Set the figure size
fig.set_size_inches(10, 10)

# Plot whole df first (with small size dots)
ax.scatter(x=df['log2FoldChange'], y=df['nlog10padj'], s=1, label="Not significant")

# Highlight up- or down-regulated genes
down = df[df.DE == "Down"]
down.sort_values(["padj"], inplace=True)
up = df[df.DE == "Up"]
up.sort_values(["padj"], inplace=True)

# Overlay up- and down-regulated gene dfs with larger label and specific color
ax.scatter(x=down['log2FoldChange'], y=down['nlog10padj'], s=3, label="Down-regulated", color="blue")
ax.scatter(x=up['log2FoldChange'], y=up['nlog10padj'], s=3, label="Up-regulated", color="red")

# Display names of top 20 up- or down-regulated genes
n_genes = 20
texts = []
for i in range(min(n_genes, up.shape[0])):
    texts.append(ax.text(x=up.iloc[i, 1],
                         y=up.iloc[i, 8],
                         s=up.iloc[i, 7]))
for i in range(min(n_genes, down.shape[0])):
    texts.append(ax.text(x=down.iloc[i, 1],
                         y=down.iloc[i, 8],
                         s=down.iloc[i, 7]))
adjust_text(texts, arrowprops=dict(arrowstyle="-", color='black', lw=0.5))

# Draw lines indicating lfc and padj cutoffs
ax.set_xlabel("logFC")
ax.set_ylabel("-log10(adj. p-value)")
ax.axvline(l2fc_cutoff, color="grey", linestyle="--")
ax.axvline(-l2fc_cutoff, color="grey", linestyle="--")
ax.axhline(-np.log10(pval_cutoff), color="grey", linestyle="--")

# Draw legend
ax.legend()

# Add a title to the plot
#ax.set_title("C2C12 0hr vs 72hr")
ax.set_title("Skeletal Muscle Embryonic vs PND4")

# Save the plot as a high-resolution PNG with specific width and height
#output_file = "plots/volcano_c2c12.png"
output_file = "plots/volcano_skeletal_ED_pnd04.png"
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1764438/3203361735.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.label[df.DE == "No"] = ""
# /tmp/ipykernel_1764438/3203361735.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   down.sort_values(["padj"], inplace=True)
# /tmp/ipykernel_1764438/3203361735.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   up.sort_values(["padj"], inplace=True)
