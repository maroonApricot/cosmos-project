# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
import pandas as pd
import numpy as np
from adjustText import adjust_text
import matplotlib.pylab as plt
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
data = pd.read_csv("data_adj/fixed_counts_matrix.tsv", sep="\t")
#here is where we filter out what samples we want to use
data = data.filter(items=['gene_id',
                'LB_10.5_NA_1', 'LB_10.5_NA_2','LB_11.5_NA_1', 'LB_11.5_NA_2',
                'G_4_F_1', 'G_4_F_2','G_4_M_1', 'G_4_M_2',
                'SM_0_NA_1', 'SM_0_NA_2',
                'MB_1', 'MB_2','MB_3', 'MB_4','MB_5',
                'MT_1', 'MT_2', 'MT_3', 'MT_4', 'MT_5'])
data = data.set_index(data["gene_id"])
data = data.drop('gene_id', axis=1)

# %%
data.head()
# Out:
#                       LB_10.5_NA_1  LB_10.5_NA_2  LB_11.5_NA_1  LB_11.5_NA_2  \
# gene_id
# ENSMUSG00000099183.1             0             0             0             0
# ENSMUSG00000065559.1            96           350          1561          1909
# ENSMUSG00000065480.1             4            25            92            83
# ENSMUSG00000065405.3         18023         20008         13458         15665
# ENSMUSG00000065567.1           125            57           111            71
#
#                       G_4_F_1  G_4_F_2  G_4_M_1  G_4_M_2  SM_0_NA_1  \
# gene_id
# ENSMUSG00000099183.1        2        4        1        8          1
# ENSMUSG00000065559.1   720323   517475   652657      101     298316
# ENSMUSG00000065480.1      444      373      427       10       2556
# ENSMUSG00000065405.3    26029    16861    16800    17258      17696
# ENSMUSG00000065567.1      213      240      186     1986         51
#
#                       SM_0_NA_2    MB_1    MB_2    MB_3    MB_4    MB_5  \
# gene_id
# ENSMUSG00000099183.1          4      12       4       0       0       1
# ENSMUSG00000065559.1     447669   70786   15451   27143   24389   27329
# ENSMUSG00000065480.1       4440    2433     306     334     359    1088
# ENSMUSG00000065405.3      20188  223146  132440  125913  135138  120392
# ENSMUSG00000065567.1         87    5289    1440    2074    1710    2018
#
#                          MT_1     MT_2     MT_3     MT_4     MT_5
# gene_id
# ENSMUSG00000099183.1       12       19        6        2        4
# ENSMUSG00000065559.1  2584038  4111798  1074677  1300194  1256891
# ENSMUSG00000065480.1   103180   104254    26475    26033    21244
# ENSMUSG00000065405.3    46398    64996    27729    28878    25335
# ENSMUSG00000065567.1      535      812      517      529      416

# %%
metadata = pd.read_csv("data_adj/metadata.tsv", sep="\t",
                      usecols=["File.accession", "Biosample.term.name", "Age", "Sample"])

# %%
# Filter metadata DataFrame based on matching samples in merged_df
metadata_filtered = metadata[metadata['Sample'].isin(data.columns)].copy()

# Sort filtered_metadata based on the order of columns in merged_df
metadata_filtered['Sample'] = pd.Categorical(metadata_filtered['Sample'], categories=data.columns)
metadata_filtered.sort_values('Sample', inplace=True)

# %%
filtering = {'Biosample.term.name': ['C2C12', 'skeletal muscle tissue'],#whatever you need from the biosample names
             'Age': ["0","PND_0"]}
group = 'Biosample.term.name' # change to the group you're interested in making the comparison in

# %%
metadata_selected = metadata_filtered.copy(deep=True)

# %%
for col in filtering.keys():
    metadata_selected = metadata_selected[metadata_selected[col].isin(filtering[col])]

# %%
metadata_selected
# Out:
#     File.accession     Biosample.term.name    Age     Sample
# 47     ENCFF431VHL  skeletal muscle tissue  PND_0  SM_0_NA_1
# 49     ENCFF430EME  skeletal muscle tissue  PND_0  SM_0_NA_2
# 0      ENCFF784UWQ                   C2C12      0       MB_1
# 1      ENCFF094EFP                   C2C12      0       MB_2
# 51  Ctrl_0hr_A_new                   C2C12      0       MB_3
# 52  Ctrl_0hr_B_new                   C2C12      0       MB_4
# 53  Ctrl_0hr_C_new                   C2C12      0       MB_5

# %%
metadata_selected.index = metadata_selected['Sample']
data_selected = data.loc[:, metadata_selected['Sample']]

# %%
data_selected
# Out:
#                       SM_0_NA_1  SM_0_NA_2    MB_1    MB_2    MB_3    MB_4  \
# gene_id
# ENSMUSG00000099183.1          1          4      12       4       0       0
# ENSMUSG00000065559.1     298316     447669   70786   15451   27143   24389
# ENSMUSG00000065480.1       2556       4440    2433     306     334     359
# ENSMUSG00000065405.3      17696      20188  223146  132440  125913  135138
# ENSMUSG00000065567.1         51         87    5289    1440    2074    1710
# ...                         ...        ...     ...     ...     ...     ...
# ENSMUSG00000099172.1          0          0       0       0       0       0
# ENSMUSG00000093219.1          0          1      13       3       1       1
# ENSMUSG00000065602.1       5658       5973   57897   15115    4542    5196
# ENSMUSG00000065536.2      12613      14819  189764   38714    5384    5343
# ENSMUSG00000106618.1          0          0       0       0       0       0
#
#                         MB_5
# gene_id
# ENSMUSG00000099183.1       1
# ENSMUSG00000065559.1   27329
# ENSMUSG00000065480.1    1088
# ENSMUSG00000065405.3  120392
# ENSMUSG00000065567.1    2018
# ...                      ...
# ENSMUSG00000099172.1       0
# ENSMUSG00000093219.1       0
# ENSMUSG00000065602.1    4304
# ENSMUSG00000065536.2    4217
# ENSMUSG00000106618.1       0
#
# [1096 rows x 7 columns]

# %%
metadata_selected
# Out:
#            File.accession     Biosample.term.name    Age     Sample
# Sample
# SM_0_NA_1     ENCFF431VHL  skeletal muscle tissue  PND_0  SM_0_NA_1
# SM_0_NA_2     ENCFF430EME  skeletal muscle tissue  PND_0  SM_0_NA_2
# MB_1          ENCFF784UWQ                   C2C12      0       MB_1
# MB_2          ENCFF094EFP                   C2C12      0       MB_2
# MB_3       Ctrl_0hr_A_new                   C2C12      0       MB_3
# MB_4       Ctrl_0hr_B_new                   C2C12      0       MB_4
# MB_5       Ctrl_0hr_C_new                   C2C12      0       MB_5

# %%
dds = DeseqDataSet(
    counts=data_selected.T,
    clinical=metadata_selected,
    design_factors=group,
    refit_cooks=True)

dds.deseq2()
stat_res = DeseqStats(dds, 
                      contrast=[group] + filtering[group])
stat_res.summary()
# Out:
# Fitting size factors...
# ... done in 0.00 seconds.
# /opt/apps/python/3.8.0/lib/python3.8/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Fitting dispersions...
# ... done in 5.19 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.96 seconds.
#
# Fitting MAP dispersions...
# ... done in 4.06 seconds.
#
# Fitting LFCs...
# ... done in 1.72 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# ... done in 1.05 seconds.
#
# Log2 fold change & Wald test p-value: Biosample.term.name C2C12 vs skeletal muscle tissue
#                            baseMean  log2FoldChange     lfcSE      stat  \
# gene_id
# ENSMUSG00000099183.1       2.363381       -1.681712  1.390987 -1.209007
# ENSMUSG00000065559.1  234195.656250       -5.047933  0.528672 -9.548333
# ENSMUSG00000065480.1    2427.860596       -3.647146  0.755210 -4.829313
# ENSMUSG00000065405.3   92805.000000        1.536057  0.517300  2.969375
# ENSMUSG00000065567.1    1285.109375        3.636858  0.498794  7.291301
# ...                             ...             ...       ...       ...
# ENSMUSG00000099172.1       0.000000             NaN       NaN       NaN
# ENSMUSG00000093219.1       1.299136        0.771175  1.653066  0.466512
# ENSMUSG00000065602.1    9145.154297       -0.612402  0.508018 -1.205472
# ENSMUSG00000065536.2   20664.533203       -0.697426  1.003119 -0.695258
# ENSMUSG00000106618.1       0.000000             NaN       NaN       NaN
#
#                             pvalue          padj
# gene_id
# ENSMUSG00000099183.1  2.266603e-01  3.738001e-01
# ENSMUSG00000065559.1  1.318005e-21  1.517902e-20
# ENSMUSG00000065480.1  1.370046e-06  7.513509e-06
# ENSMUSG00000065405.3  2.984059e-03  1.005846e-02
# ENSMUSG00000065567.1  3.069753e-13  2.828265e-12
# ...                            ...           ...
# ENSMUSG00000099172.1           NaN           NaN
# ENSMUSG00000093219.1  6.408489e-01  7.392765e-01
# ENSMUSG00000065602.1  2.280210e-01  3.751488e-01
# ENSMUSG00000065536.2  4.868937e-01  6.139481e-01
# ENSMUSG00000106618.1           NaN           NaN
#
# [1096 rows x 6 columns]

# %%
l2fc_cutoff = 2 # Log 2 fold change; usually 0.5 - 2
pval_cutoff = 0.05 # 0.01 is even better than 0.05

# %%
annot = pd.read_csv("data_adj/mirna_id_to_name.tsv", sep="\t")
annot.drop(columns=['Unnamed: 0'], inplace=True)

# %%
annot.head()
# Out:
#                 gene_id gene_name
# 0  ENSMUSG00000065559.1    Mir206
# 1  ENSMUSG00000065480.1   Mir133b
# 2  ENSMUSG00000065567.1  Mir30c-2
# 3  ENSMUSG00000105982.1   Mir6896
# 4  ENSMUSG00000092852.1   Mir5103

# %%
df = stat_res.results_df.copy(deep=True)

# %%
# Find the machine-specific lowest non-zero value
lowest_nonzero_value = df['padj'][df['padj'] > 0].min()

# Replace 0 with the lowest non-zero value
df['padj'] = np.where(df['padj'] == 0, lowest_nonzero_value, df['padj'])

df = df.dropna()
df = df.merge(annot, left_index=True, right_on='gene_id')
df
# Out:
#           baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0    234195.656250       -5.047933  0.528672 -9.548333  1.318005e-21
# 1      2427.860596       -3.647146  0.755210 -4.829313  1.370046e-06
# 818   92805.000000        1.536057  0.517300  2.969375  2.984059e-03
# 2      1285.109375        3.636858  0.498794  7.291301  3.069753e-13
# 3         5.308888        0.187428  1.008698  0.185812  8.525924e-01
# ..             ...             ...       ...       ...           ...
# 809       1.416556       -4.662084  1.975183 -2.360330  1.825867e-02
# 810       2.341686       -4.741310  2.016484 -2.351276  1.870914e-02
# 813       1.299136        0.771175  1.653066  0.466512  6.408489e-01
# 814    9145.154297       -0.612402  0.508018 -1.205472  2.280210e-01
# 815   20664.533203       -0.697426  1.003119 -0.695258  4.868937e-01
#
#              padj               gene_id   gene_name
# 0    1.517902e-20  ENSMUSG00000065559.1      Mir206
# 1    7.513509e-06  ENSMUSG00000065480.1     Mir133b
# 818  1.005846e-02  ENSMUSG00000065405.3      Mir30a
# 2    2.828265e-12  ENSMUSG00000065567.1    Mir30c-2
# 3    9.091687e-01  ENSMUSG00000105982.1     Mir6896
# ..            ...                   ...         ...
# 809  4.871328e-02  ENSMUSG00000093122.1     Mir1264
# 810  4.934356e-02  ENSMUSG00000080331.1     Mir1298
# 813  7.392765e-01  ENSMUSG00000093219.1     Mir3113
# 814  3.751488e-01  ENSMUSG00000065602.1  Mirlet7f-2
# 815  6.139481e-01  ENSMUSG00000065536.2       Mir98
#
# [660 rows x 8 columns]

# %%
# Calculate -log10(padj)
df['nlog10padj'] = -np.log10(df['padj'])

# Add labels to DE column based on our cutoffs above
df['DE'] = "No"
df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange > l2fc_cutoff)] = "Up"
df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange < -l2fc_cutoff)] = "Down"
# Out:
# /tmp/ipykernel_2226678/1959988433.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange > l2fc_cutoff)] = "Up"
# /tmp/ipykernel_2226678/1959988433.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.DE[np.logical_and(df.padj < pval_cutoff, df.log2FoldChange < -l2fc_cutoff)] = "Down"

# %%
df
# Out:
#           baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 0    234195.656250       -5.047933  0.528672 -9.548333  1.318005e-21
# 1      2427.860596       -3.647146  0.755210 -4.829313  1.370046e-06
# 818   92805.000000        1.536057  0.517300  2.969375  2.984059e-03
# 2      1285.109375        3.636858  0.498794  7.291301  3.069753e-13
# 3         5.308888        0.187428  1.008698  0.185812  8.525924e-01
# ..             ...             ...       ...       ...           ...
# 809       1.416556       -4.662084  1.975183 -2.360330  1.825867e-02
# 810       2.341686       -4.741310  2.016484 -2.351276  1.870914e-02
# 813       1.299136        0.771175  1.653066  0.466512  6.408489e-01
# 814    9145.154297       -0.612402  0.508018 -1.205472  2.280210e-01
# 815   20664.533203       -0.697426  1.003119 -0.695258  4.868937e-01
#
#              padj               gene_id   gene_name  nlog10padj    DE
# 0    1.517902e-20  ENSMUSG00000065559.1      Mir206   19.818756  Down
# 1    7.513509e-06  ENSMUSG00000065480.1     Mir133b    5.124157  Down
# 818  1.005846e-02  ENSMUSG00000065405.3      Mir30a    1.997468    No
# 2    2.828265e-12  ENSMUSG00000065567.1    Mir30c-2   11.548480    Up
# 3    9.091687e-01  ENSMUSG00000105982.1     Mir6896    0.041356    No
# ..            ...                   ...         ...         ...   ...
# 809  4.871328e-02  ENSMUSG00000093122.1     Mir1264    1.312353  Down
# 810  4.934356e-02  ENSMUSG00000080331.1     Mir1298    1.306769  Down
# 813  7.392765e-01  ENSMUSG00000093219.1     Mir3113    0.131193    No
# 814  3.751488e-01  ENSMUSG00000065602.1  Mirlet7f-2    0.425796    No
# 815  6.139481e-01  ENSMUSG00000065536.2       Mir98    0.211868    No
#
# [660 rows x 10 columns]

# %%
df.to_csv("data_adj/deg_quantity/MB_PND0.tsv", sep="\t", columns=["gene_name", "DE"])

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text

df['label'] = df.gene_name
df.label[df.DE == "No"] = ""

# Create the figure
fig, ax = plt.subplots()

# Set the figure size
fig.set_size_inches(10, 10)

# Plot whole df first (with small size dots)
ax.scatter(x=df['log2FoldChange'], y=df['nlog10padj'], s=1, label="Not significant")

# Highlight up- or down-regulated genes
down = df[df.DE == "Down"]
down.sort_values(["padj"], inplace=True)
up = df[df.DE == "Up"]
up.sort_values(["padj"], inplace=True)

# Overlay up- and down-regulated gene dfs with larger label and specific color
ax.scatter(x=down['log2FoldChange'], y=down['nlog10padj'], s=3, label="Down-regulated", color="blue")
ax.scatter(x=up['log2FoldChange'], y=up['nlog10padj'], s=3, label="Up-regulated", color="red")

# Display names of top 20 up- or down-regulated genes
n_genes = 20
texts = []
for i in range(min(n_genes, up.shape[0])):
    texts.append(ax.text(x=up.iloc[i, 1],
                         y=up.iloc[i, 8],
                         s=up.iloc[i, 7]))
for i in range(min(n_genes, down.shape[0])):
    texts.append(ax.text(x=down.iloc[i, 1],
                         y=down.iloc[i, 8],
                         s=down.iloc[i, 7]))
adjust_text(texts, arrowprops=dict(arrowstyle="-", color='black', lw=0.5))

# Draw lines indicating lfc and padj cutoffs
ax.set_xlabel("logFC")
ax.set_ylabel("-log10(adj. p-value)")
ax.axvline(l2fc_cutoff, color="grey", linestyle="--")
ax.axvline(-l2fc_cutoff, color="grey", linestyle="--")
ax.axhline(-np.log10(pval_cutoff), color="grey", linestyle="--")

# Draw legend
ax.legend()

# Add a title to the plot
ax.set_title("C2C12 0hr vs PND0")
#ax.set_title("Skeletal Muscle Embryonic vs PND0")

# Save the plot as a high-resolution PNG with specific width and height
output_file = "plots/volcano_MB_PND0.png"
#output_file = "plots/volcano_skeletal.png"
plt.savefig(output_file, dpi=300)

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_2226130/3248677025.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.label[df.DE == "No"] = ""
# /tmp/ipykernel_2226130/3248677025.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   down.sort_values(["padj"], inplace=True)
# /tmp/ipykernel_2226130/3248677025.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   up.sort_values(["padj"], inplace=True)
