# %%
import pandas as pd

# %%
df = pd.read_table("/data/class/cosmos2023/PUBLIC/shai_hulud/data/mirna/gastroc/GSM6783220_ENCFF286MEN_microRNA_quantifications_mm10.tsv")

# %%
filtered_df = df[df.sum(axis=1, numeric_only=True)>0]
filtered_df.head(n=20)
# Out:
#               N_unmapped   622728  622728.1  622728.2
# 0         N_multimapping  3266711   3266711   3266711
# 1            N_noFeature   277539    277601   2485629
# 2            N_ambiguous   864996         0         0
# 7   ENSMUSG00000099183.1        8         8         0
# 9   ENSMUSG00000065559.1      101       101         0
# 10  ENSMUSG00000065480.1       10        10         0
# 11  ENSMUSG00000065405.3    17258     17258         0
# 12  ENSMUSG00000065567.1     1986      1986         0
# 19  ENSMUSG00000092852.1        1         1         0
# 20  ENSMUSG00000098752.1        6         6         0
# 27  ENSMUSG00000105211.1        2         2         0
# 40  ENSMUSG00000092705.1        3         0         3
# 47  ENSMUSG00000065468.1    73808     73808         0
# 49  ENSMUSG00000065616.3      145       145         0
# 58  ENSMUSG00000093254.1        6         6         0
# 60  ENSMUSG00000098634.1        1         1         0
# ...

# %%
filtered_df.shape
# Out:
# (634, 4)
